# %%
import pandas as pd
import re

# %%
def Find_MCA(tt):
    ttt = pd.DataFrame(tt["description"])
    #ttt["transaction_type"] = tt["transaction_type"]
    cnt=1
    print(tt["transaction_type"].unique()[0])
    for j in lst:
        print(cnt)
        print(j)
        print("\n")
        for i in ttt["description"]:
            try:
                if re.search(r"(?i)\b"+j+r"",i):
                    print(i)
            except:
                None
        cnt+=1
        print("\n\n\n")

# %%
#202006-202106
'''df = pd.read_csv("df_trx_202001_202106.csv")
print(len(df["Lead Id"]))
df.head()
df["post_date"] = pd.to_datetime(df["post_date"])

df_20q1 = df.loc[df["post_date"]<= "2020-03-31"]
df_20q2 = df.loc[(df["post_date"]>= "2020-04-01") & (df["post_date"]<= "2020-06-30")]
df_20q3 = df.loc[(df["post_date"]>= "2020-07-01") & (df["post_date"]<= "2020-09-30")]
df_20q4 = df.loc[(df["post_date"]>= "2020-10-01") & (df["post_date"]<= "2020-12-31")]
df_21q1 = df.loc[(df["post_date"]>= "2021-01-01") & (df["post_date"]<= "2021-03-31")]
df_21q2 = df.loc[(df["post_date"]>= "2021-04-01") & (df["post_date"]<= "2021-06-30")]

df_20q1.to_csv("df_202001.csv")
df_20q2.to_csv("df_202004.csv")
df_20q3.to_csv("df_202007.csv")
df_20q4.to_csv("df_202010.csv")
df_21q1.to_csv("df_202101.csv")
df_21q2.to_csv("df_202104.csv")'''
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\nelson.wang\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 225, in read
#     data = _concatenate_chunks(chunks)
#   File "C:\Users\nelson.wang\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 387, in _concatenate_chunks
#     result[name] = np.concatenate(arrs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\nelson.wang\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\NELSON~2.WAN\AppData\Local\Temp/ipykernel_17772/888544603.py", line 1, in <module>
#     df = pd.read_csv("df_trx_202001_202106.csv")
# ...

# %%
#202107-202208:

df = pd.read_csv("df_trx_202107_202208.csv")
print(len(df["Lead Id"]))
df["post_date"] = pd.to_datetime(df["post_date"])
df_21q3 = df.loc[(df["post_date"]>= "2021-07-01") & (df["post_date"]<= "2021-09-30")]
df_21q4 = df.loc[(df["post_date"]>= "2021-10-01") & (df["post_date"]<= "2021-12-31")]
df_22q1 = df.loc[(df["post_date"]<= "2022-03-31") & (df["post_date"]>= "2022-01-01")]
df_22q2 = df.loc[(df["post_date"]>= "2022-04-01") & (df["post_date"]<= "2022-06-30")]
df_22q3 = df.loc[df["post_date"]>= "2022-07-01"]


df_22q1.to_csv("df_202201.csv")
df_22q2.to_csv("df_202204.csv")
df_22q3.to_csv("df_202207.csv")
df_21q3.to_csv("df_202107.csv")
df_21q4.to_csv("df_202110.csv")
# Out:
# 35542773

# %% [markdown]
# ## 2020

# %%
# %%time
df_20q1 = pd.read_csv("df_202001.csv")
df_20q2= pd.read_csv("df_202004.csv")
df_20q3= pd.read_csv("df_202007.csv")
df_20q4= pd.read_csv("df_202010.csv")
# Out:
# Wall time: 41.7 s

# %%
# %%time
df_20q1_cr = df_20q1.loc[df_20q1["transaction_type"]=="credit"]
df_20q1_db = df_20q1.loc[df_20q1["transaction_type"]=="debit"]

df_20q2_cr = df_20q2.loc[df_20q2["transaction_type"]=="credit"]
df_20q2_db = df_20q2.loc[df_20q2["transaction_type"]=="debit"]

df_20q3_cr = df_20q3.loc[df_20q3["transaction_type"]=="credit"]
df_20q3_db = df_20q3.loc[df_20q3["transaction_type"]=="debit"]

df_20q4_cr = df_20q4.loc[df_20q4["transaction_type"]=="credit"]
df_20q4_db = df_20q4.loc[df_20q4["transaction_type"]=="debit"]

# %% [markdown]
# # 2021

# %%
df_21q1= pd.read_csv("df_202101.csv")
df_21q2= pd.read_csv("df_202104.csv")
df_21q3= pd.read_csv("df_202107.csv")
df_21q4= pd.read_csv("df_202110.csv")

# %%
df_21q1_cr = df_21q1.loc[df_21q1["transaction_type"]=="credit"]
df_21q1_db = df_21q1.loc[df_21q1["transaction_type"]=="debit"]

df_21q2_cr = df_21q2.loc[df_21q2["transaction_type"]=="credit"]
df_21q2_db = df_21q2.loc[df_21q2["transaction_type"]=="debit"]

df_21q3_cr = df_21q3.loc[df_21q3["transaction_type"]=="credit"]
df_21q3_db = df_21q3.loc[df_21q3["transaction_type"]=="debit"]

df_21q4_cr = df_21q4.loc[df_21q4["transaction_type"]=="credit"]
df_21q4_db = df_21q4.loc[df_21q4["transaction_type"]=="debit"]

# %%
df_21q4= pd.read_csv("df_202110.csv")
df_21q4_cr = df_21q4.loc[df_21q4["transaction_type"]=="credit"]
df_21q4_db = df_21q4.loc[df_21q4["transaction_type"]=="debit"]

# %%
df_21q4_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6582049 entries, 0 to 8562617
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Unnamed: 0.1      int64
#  2   Lead Id           int64
#  3   account_number    object
#  4   post_date         object
#  5   description       object
#  6   transaction_type  object
#  7   amount            float64
#  8   running_balance   float64
#  9   Classification    object
#  10  Source_class      object
#  11  Source            object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 652.8+ MB

# %% [markdown]
# # 2022:

# %%
df_22q1 = pd.read_csv("df_202201.csv")
df_22q2 = pd.read_csv("df_202204.csv")
df_22q3 = pd.read_csv("df_202207.csv")

# %%
df_22q1_cr = df_22q1.loc[df_22q1["transaction_type"]=="credit"]
df_22q1_db = df_22q1.loc[df_22q1["transaction_type"]=="debit"]

df_22q2_cr = df_22q2.loc[df_22q2["transaction_type"]=="credit"]
df_22q2_db = df_22q2.loc[df_22q2["transaction_type"]=="debit"]

df_22q3_cr = df_22q3.loc[df_22q3["transaction_type"]=="credit"]
df_22q3_db = df_22q3.loc[df_22q3["transaction_type"]=="debit"]

# %% [markdown]
# # 22 Q3 202207

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
len(lst)
# Out:
# 38

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_22q3_cr
Find_MCA(tt)
# Out:
# credit
# 1
# fast cash
#
#
# WT FED#X4269 CAPITAL ONE, NA       /ORG=RELIABLE FAST CASH LLC                        SRF#      USXXXXXXXX6569 TRN#XXXXXXXX3448  RFB#          XXXXXX6152
#
#
#
#
# Wall time: 1.98 s

# %% [markdown]
# ### Debit:

# %%
lst = ["fast cash"]

# %%
# %%time
tt = df_22q3_db
Find_MCA(tt)
# Out:
# debit
# 1
# fast cash
#
#
# CHECKCARD  XXXX 500 FAST CASH XXXXX5821                     XXX-XXX-5859 OK XXXXX4721XXXXXXXXXX9049
# CHECKCARD  XXXX 500 FAST CASH XXXXX5821                     XXX-XXX-5859 OK XXXXX4721XXXXXXXXXX7241
#
#
#
#
# Wall time: 6.08 s

# %% [markdown]
# # 22 Q2 202204

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_22q2_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_22q2_db
Find_MCA(tt)

# %% [markdown]
# # 22 Q1 202201

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_22q1_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_22q1_db
Find_MCA(tt)

# %% [markdown]
# # 21 Q4 202110

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_21q4_cr
Find_MCA(tt)
print(

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_21q4_db
Find_MCA(tt)

# %% [markdown]
# # 21 Q3 202107

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_21q3_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
tt = df_21q3_db
Find_MCA(tt)

# %% [markdown]
# # 21 Q2 202104

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_21q2_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
tt = df_21q2_db
Find_MCA(tt)

# %% [markdown]
# # 21 Q1 202101

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_21q1_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_21q1_db
Find_MCA(tt)

# %% [markdown]
# # 20 Q4 202010

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_20q4_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
tt = df_20q4_db
Find_MCA(tt)

# %% [markdown]
# # 20 Q3 202007

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_20q3_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_20q3_db
Find_MCA(tt)

# %% [markdown]
# # 20 Q2 202004

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_20q2_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_20q2_db
Find_MCA(tt)

# %% [markdown]
# # 20 Q1 202001

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
lst

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_20q1_cr
Find_MCA(tt)

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_20q1_db
Find_MCA(tt)

# %% [markdown]
# # Mega File

# %% [markdown]
# ## 2021-2022

# %%
df_22 = pd.read_csv("df_trx_202107_202208.csv")
df_22_cr = df_22.loc[df_22["transaction_type"]=="credit"]
df_22_db = df_22.loc[df_22["transaction_type"]=="debit"]
df_22_cr.info()
df_22_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8241184 entries, 14 to 35542767
# Data columns (total 11 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Lead Id           int64
#  2   account_number    object
#  3   post_date         object
#  4   description       object
#  5   transaction_type  object
#  6   amount            float64
#  7   running_balance   float64
#  8   Classification    object
#  9   Source_class      object
#  10  Source            object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 754.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27301577 entries, 0 to 35542772
# Data columns (total 11 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Lead Id           int64
#  2   account_number    object
#  3   post_date         object
#  4   description       object
#  5   transaction_type  object
# ...

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
len(lst)
# Out:
# 38

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_22_cr
Find_MCA(tt)
# Out:
# credit
# 1
# 6thavec
#
#
#
#
#
#
# 2
# 6th Ave Cap
#
#
#
#
#
#
# 3
# Acarius
#
#
#
#
#
#
# 4
# Basepoint
#
#
#
#
#
#
# 5
# BFS cap
#
#
#
#
#
#
# 6
# Bluebridge
#
#
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 96471875
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 97036585
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 97076464
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 97076530
# BLUEBRIDGECAP    XXXXXX1000
# BLUEBRIDGECAP    XXXXXX1000
#
#
#
#
# 7
# Canacap
#
#
#
#
#
#
# 8
# CapFundNow
#
#
#
#
#
#
# 9
# Cap Fund Now
#
#
#
#
#
#
# 10
# Capback
#
#
#
#
#
#
# 11
# Central Diligence
#
#
#
#
#
#
# 12
# CentralDiligence
#
#
#
#
#
#
# 13
# Cvelocity
#
#
#
#
#
#
# 14
# delancey
#
#
# ATM CHECK DEPOSIT 07/02 109 DELANCEY ST NEW YORK NY
# BKOFAMERICA ATM 08/28 #000007643 DEPOSIT DELANCEY AND LUD NEW YORK NY
# BKOFAMERICA ATM 08/28 #000007646 DEPOSIT DELANCEY AND LUD NEW YORK NY
# Mobile Payment ID: 8HV42861M98854343 name:Amanda Delancey email:adelancey18@gmail.com
# ...

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_22_db
Find_MCA(tt)
# Out:
# debit
# 1
# 6thavec
#
#
#
#
#
#
# 2
# 6th Ave Cap
#
#
#
#
#
#
# 3
# Acarius
#
#
#
#
#
#
# 4
# Basepoint
#
#
#
#
#
#
# 5
# BFS cap
#
#
#
#
#
#
# 6
# Bluebridge
#
#
# zelle payment to bluebridge 12656037893
# zelle payment to bluebridge 12698267928
# Zelle payment to BlueBridge  XXXXXXX7893
# Zelle payment to BlueBridge  XXXXXXX7928
# BUSINESS TO BUSINESS ACH BlueBridgeCap    XXXXXXXXXX        XXXX3814        J AND B ASSOCIATES LLC
# zelle payment to bluebridge 13025413913
# zelle payment to bluebridge 13069833155
# zelle payment to bluebridge 13125346538
# zelle payment to bluebridge 13191109557
# zelle payment to bluebridge 13232054825
# zelle payment to bluebridge 13232353820
# zelle payment to bluebridge 13267331669
# zelle payment to bluebridge 13281471848
# zelle payment to bluebridge 13297957613
# zelle payment to bluebridge 13310354320
# CCD DEBIT, BLUEBRIDGECAP 2124441000 96035696
# CCD DEBIT, BLUEBRIDGECAP 2124441000 96049989
# CCD DEBIT, BLUEBRIDGECAP 2124441000 96064450
# ...

# %% [markdown]
# ## 2020-2021

# %%
df_20 = pd.read_csv("df_trx_202001_202106.csv")
df_20_cr = df_20.loc[df_20["transaction_type"]=="credit"]
df_20_db = df_20.loc[df_20["transaction_type"]=="debit"]
df_20_cr.info()
df_20_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11945715 entries, 6 to 48278831
# Data columns (total 11 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Lead Id           int64
#  2   account_number    object
#  3   post_date         object
#  4   description       object
#  5   transaction_type  object
#  6   amount            float64
#  7   running_balance   float64
#  8   Classification    object
#  9   Source_class      object
#  10  Source            object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.1+ GB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36333001 entries, 0 to 48278836
# Data columns (total 11 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Lead Id           int64
#  2   account_number    object
#  3   post_date         object
#  4   description       object
#  5   transaction_type  object
# ...

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Further")
lst = list(df["Search"])
len(lst)
# Out:
# 38

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_22_cr
Find_MCA(tt)
# Out:
# credit
# 1
# 6thavec
#
#
#
#
#
#
# 2
# 6th Ave Cap
#
#
#
#
#
#
# 3
# Acarius
#
#
#
#
#
#
# 4
# Basepoint
#
#
#
#
#
#
# 5
# BFS cap
#
#
#
#
#
#
# 6
# Bluebridge
#
#
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 96471875
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 97036585
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 97076464
# ACH RETURNED ITEM, BLUEBRIDGECAP 2124441000 97076530
# BLUEBRIDGECAP    XXXXXX1000
# BLUEBRIDGECAP    XXXXXX1000
#
#
#
#
# 7
# Canacap
#
#
#
#
#
#
# 8
# CapFundNow
#
#
#
#
#
#
# 9
# Cap Fund Now
#
#
#
#
#
#
# 10
# Capback
#
#
#
#
#
#
# 11
# Central Diligence
#
#
#
#
#
#
# 12
# CentralDiligence
#
#
#
#
#
#
# 13
# Cvelocity
#
#
#
#
#
#
# 14
# delancey
#
#
# ATM CHECK DEPOSIT 07/02 109 DELANCEY ST NEW YORK NY
# BKOFAMERICA ATM 08/28 #000007643 DEPOSIT DELANCEY AND LUD NEW YORK NY
# BKOFAMERICA ATM 08/28 #000007646 DEPOSIT DELANCEY AND LUD NEW YORK NY
# Mobile Payment ID: 8HV42861M98854343 name:Amanda Delancey email:adelancey18@gmail.com
# ...

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_22_db
Find_MCA(tt)
# Out:
# debit
# 1
# 6thavec
#
#
#
#
#
#
# 2
# 6th Ave Cap
#
#
#
#
#
#
# 3
# Acarius
#
#
#
#
#
#
# 4
# Basepoint
#
#
#
#
#
#
# 5
# BFS cap
#
#
#
#
#
#
# 6
# Bluebridge
#
#
# zelle payment to bluebridge 12656037893
# zelle payment to bluebridge 12698267928
# Zelle payment to BlueBridge  XXXXXXX7893
# Zelle payment to BlueBridge  XXXXXXX7928
# BUSINESS TO BUSINESS ACH BlueBridgeCap    XXXXXXXXXX        XXXX3814        J AND B ASSOCIATES LLC
# zelle payment to bluebridge 13025413913
# zelle payment to bluebridge 13069833155
# zelle payment to bluebridge 13125346538
# zelle payment to bluebridge 13191109557
# zelle payment to bluebridge 13232054825
# zelle payment to bluebridge 13232353820
# zelle payment to bluebridge 13267331669
# zelle payment to bluebridge 13281471848
# zelle payment to bluebridge 13297957613
# zelle payment to bluebridge 13310354320
# CCD DEBIT, BLUEBRIDGECAP 2124441000 96035696
# CCD DEBIT, BLUEBRIDGECAP 2124441000 96049989
# CCD DEBIT, BLUEBRIDGECAP 2124441000 96064450
# ...

# %% [markdown]
# # 2019

# %%
df_19 = pd.read_csv("df_trx_2019.csv")
df_19_cr = df_19.loc[df_19["transaction_type"]=="credit"]
df_19_db = df_19.loc[df_19["transaction_type"]=="debit"]
df_19_cr.info()
df_19_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3083774 entries, 2 to 12009089
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Unnamed: 0.1      int64
#  2   Lead Id           int64
#  3   account_number    object
#  4   post_date         object
#  5   description       object
#  6   transaction_type  object
#  7   amount            float64
#  8   running_balance   float64
#  9   Classification    object
#  10  Source_class      object
#  11  Source            object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 305.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8925129 entries, 0 to 12009093
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   Unnamed: 0.1      int64
#  2   Lead Id           int64
#  3   account_number    object
#  4   post_date         object
# ...

# %% [markdown]
# ### Credit:

# %%
# %%time
tt = df_19_cr
Find_MCA(tt)
# Out:
# credit
# 1
# 6thavec
#
#
#
#
#
#
# 2
# 6th Ave Cap
#
#
# ONLINE TRANSFER FROM THE 3 AMIGOS RESTAURANT GROUP, LLC REF #IB05Y7WG37 BUSINESS CHECKING INVESTED DEBT 6TH AVE CAPITAL
#
#
#
#
# 3
# Acarius
#
#
#
#
#
#
# 4
# Basepoint
#
#
#
#
#
#
# 5
# BFS cap
#
#
#
#
#
#
# 6
# Bluebridge
#
#
#
#
#
#
# 7
# Canacap
#
#
#
#
#
#
# 8
# CapFundNow
#
#
#
#
#
#
# 9
# Cap Fund Now
#
#
#
#
#
#
# 10
# Capback
#
#
#
#
#
#
# 11
# Central Diligence
#
#
#
#
#
#
# 12
# CentralDiligence
#
#
#
#
#
#
# 13
# Cvelocity
#
#
#
#
#
#
# 14
# delancey
#
#
# ATM CHECK DEPOSIT 01/22 109 DELANCEY ST NEW YORK NY
# ATM CASH DEPOSIT 01/23 109 DELANCEY ST NEW YORK NY
# ATM CASH DEPOSIT 01/23 109 DELANCEY ST NEW YORK NY
# ATM CASH DEPOSIT 01/23 109 DELANCEY ST NEW YORK NY
# BKOFAMERICA ATM 04/05 #000004272 DEPOSIT DELANCEY AND LUD NEW YORK NY
# BKOFAMERICA ATM 04/10 #000006824 DEPOSIT DELANCEY AND LUD NEW YORK NY
# BKOFAMERICA ATM 04/16 #000002470 DEPOSIT DELANCEY AND LUD NEW YORK NY
# ...

# %% [markdown]
# ### Debit:

# %%
# %%time
tt = df_19_db
Find_MCA(tt)
# Out:
# debit
# 1
# 6thavec
#
#
#
#
#
#
# 2
# 6th Ave Cap
#
#
# ONLINE TRANSFER TO THE 3 AMIGOS RESTAURANT GROUP, LLC REF #IB05Y7WG37 BUSINESS PLATINUM SAVINGS INVESTED DEBT 6TH AVE CAPITAL
#
#
#
#
# 3
# Acarius
#
#
#
#
#
#
# 4
# Basepoint
#
#
#
#
#
#
# 5
# BFS cap
#
#
# TRANSFER AFFINITY DESIGNS LLC:BFS CAPITAL Confirmation# 1710729525
# TRANSFER AFFINITY DESIGNS LLC:BFS CAPITAL Confirmation# 0140382646
# TRANSFER AFFINITY DESIGNS LLC:BFS CAPITAL Confirmation# 1784892459
# WIRE TYPE:WIRE OUT DATE:190430 TIME:0938 ET TRN:2019043000296596 SERVICE REF:006364 BNF:BFS CAPITAL ID:4000140707 BNF BK:WELLS FARGO B ANK, N.A. ID:121000248 PMT DET:262064354
# TRANSFER AFFINITY DESIGNS LLC:BFS CAPITAL Confirmation# 0206220010
# WIRE TYPE:WIRE OUT DATE:190628 TIME:1013 ET TRN:2019062800352577 SERVICE REF:010876 BNF:BFS CAPITAL ID:4000140707 BNF BK:WELLS FARGO B ANK, N.A. ID:121000248 PMT DET:267643000
# TRANSFER AFFINITY DESIGNS LLC:BFS CAPITAL Confirmation# 4260185918
# ...

# %% [markdown]
# # Double Check:

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Check")
lst = list(df["Search"])
len(lst)
# Out:
# 20

# %%
# %%time
tt = df_19_cr
Find_MCA(tt)
# Out:
# credit
# 1
# Canacap
#
#
#
#
#
#
# 2
# Cap Fund Now
#
#
#
#
#
#
# 3
# CapFundNow
#
#
#
#
#
#
# 4
# Capback
#
#
#
#
#
#
# 5
# Central Diligence
#
#
#
#
#
#
# 6
# CentralDiligence
#
#
#
#
#
#
# 7
# Cvelocity
#
#
#
#
#
#
# 8
# delancey Street Lending
#
#
#
#
#
#
# 9
# delanceyStreetLending
#
#
#
#
#
#
# 10
# G & G Funding
#
#
#
#
#
#
# 11
# G&G Fund
#
#
#
#
#
#
# 12
# Lendbug
#
#
#
#
#
#
# 13
# Lendfi
#
#
#
#
#
#
# 14
# MonteraCap
#
#
#
#
#
#
# 15
# Montera Cap
#
#
#
#
#
#
# 16
# Quikstone
#
#
#
#
#
#
# 17
# Riverstrong
#
#
#
#
#
#
# 18
# Speciality Cap
#
#
#
#
#
#
# 19
# SpecialityCap
#
#
#
#
#
#
# 20
# United Business Fun
#
#
#
#
#
#
# Wall time: 1min 42s

# %%
# %%time
tt = df_19_db
Find_MCA(tt)
# Out:
# debit
# 1
# Canacap
#
#
#
#
#
#
# 2
# Cap Fund Now
#
#
#
#
#
#
# 3
# CapFundNow
#
#
#
#
#
#
# 4
# Capback
#
#
#
#
#
#
# 5
# Central Diligence
#
#
#
#
#
#
# 6
# CentralDiligence
#
#
#
#
#
#
# 7
# Cvelocity
#
#
#
#
#
#
# 8
# delancey Street Lending
#
#
#
#
#
#
# 9
# delanceyStreetLending
#
#
#
#
#
#
# 10
# G & G Funding
#
#
#
#
#
#
# 11
# G&G Fund
#
#
#
#
#
#
# 12
# Lendbug
#
#
#
#
#
#
# 13
# Lendfi
#
#
#
#
#
#
# 14
# MonteraCap
#
#
#
#
#
#
# 15
# Montera Cap
#
#
#
#
#
#
# 16
# Quikstone
#
#
#
#
#
#
# 17
# Riverstrong
#
#
#
#
#
#
# 18
# Speciality Cap
#
#
#
#
#
#
# 19
# SpecialityCap
#
#
#
#
#
#
# 20
# United Business Fun
#
#
#
#
#
#
# Wall time: 4min 53s

# %%
# %%time
tt = df_20_cr
Find_MCA(tt)
# Out:
# credit
# 1
# Canacap
#
#
#
#
#
#
# 2
# Cap Fund Now
#
#
#
#
#
#
# 3
# CapFundNow
#
#
#
#
#
#
# 4
# Capback
#
#
#
#
#
#
# 5
# Central Diligence
#
#
#
#
#
#
# 6
# CentralDiligence
#
#
#
#
#
#
# 7
# Cvelocity
#
#
#
#
#
#
# 8
# delancey Street Lending
#
#
#
#
#
#
# 9
# delanceyStreetLending
#
#
#
#
#
#
# 10
# G & G Funding
#
#
#
#
#
#
# 11
# G&G Fund
#
#
#
#
#
#
# 12
# Lendbug
#
#
#
#
#
#
# 13
# Lendfi
#
#
#
#
#
#
# 14
# MonteraCap
#
#
#
#
#
#
# 15
# Montera Cap
#
#
#
#
#
#
# 16
# Quikstone
#
#
#
#
#
#
# 17
# Riverstrong
#
#
#
#
#
#
# 18
# Speciality Cap
#
#
#
#
#
#
# 19
# SpecialityCap
#
#
#
#
#
#
# 20
# United Business Fun
#
#
#
#
#
#
# Wall time: 7min 8s

# %%
# %%time
tt = df_20_db
Find_MCA(tt)
# Out:
# debit
# 1
# Canacap
#
#
#
#
#
#
# 2
# Cap Fund Now
#
#
#
#
#
#
# 3
# CapFundNow
#
#
#
#
#
#
# 4
# Capback
#
#
#
#
#
#
# 5
# Central Diligence
#
#
#
#
#
#
# 6
# CentralDiligence
#
#
#
#
#
#
# 7
# Cvelocity
#
#
#
#
#
#
# 8
# delancey Street Lending
#
#
#
#
#
#
# 9
# delanceyStreetLending
#
#
#
#
#
#
# 10
# G & G Funding
#
#
#
#
#
#
# 11
# G&G Fund
#
#
#
#
#
#
# 12
# Lendbug
#
#
#
#
#
#
# 13
# Lendfi
#
#
# Direct Payment - Loan Pymt Lendfirm Llc XXXXX5505
# Direct Payment - Loan Pymt Lendfirm Llc XXXXX5505
# Lendfirm LLC Loan Pymt 031721 1559141 James Perry
# Lendfirm LLC Loan Pymt 033121 1559141 James Perry
# XX0755 LENDFIRM LLC LOAN PYMT
# XX5505 LENDFIRM LLC LOAN PYMT
# XX5505 LENDFIRM LLC LOAN PYMT
# Direct Payment - Loan Pymt Lendfirm Llc XXXXX5505
# Direct Payment - Loan Pymt Lendfirm Llc XXXXX5505
# NSF Return Item Fee for a Transaction Received on 04/14 $57.92 Lendfirm LLC Loan Pymt 041421 1559141 James Perry
# Lendfirm LLC Loan Pymt 042821 1559141 James Perry
# ...

# %%
# %%time
tt = df_22_cr
Find_MCA(tt)
# Out:
# credit
# 1
# Canacap
#
#
#
#
#
#
# 2
# Cap Fund Now
#
#
#
#
#
#
# 3
# CapFundNow
#
#
#
#
#
#
# 4
# Capback
#
#
#
#
#
#
# 5
# Central Diligence
#
#
#
#
#
#
# 6
# CentralDiligence
#
#
#
#
#
#
# 7
# Cvelocity
#
#
#
#
#
#
# 8
# delancey Street Lending
#
#
#
#
#
#
# 9
# delanceyStreetLending
#
#
#
#
#
#
# 10
# G & G Funding
#
#
#
#
#
#
# 11
# G&G Fund
#
#
#
#
#
#
# 12
# Lendbug
#
#
#
#
#
#
# 13
# Lendfi
#
#
#
#
#
#
# 14
# MonteraCap
#
#
#
#
#
#
# 15
# Montera Cap
#
#
#
#
#
#
# 16
# Quikstone
#
#
#
#
#
#
# 17
# Riverstrong
#
#
#
#
#
#
# 18
# Speciality Cap
#
#
#
#
#
#
# 19
# SpecialityCap
#
#
#
#
#
#
# 20
# United Business Fun
#
#
#
#
#
#
# Wall time: 5min 35s

# %%
# %%time
tt = df_22_db
Find_MCA(tt)
# Out:
# debit
# 1
# Canacap
#
#
#
#
#
#
# 2
# Cap Fund Now
#
#
#
#
#
#
# 3
# CapFundNow
#
#
#
#
#
#
# 4
# Capback
#
#
#
#
#
#
# 5
# Central Diligence
#
#
#
#
#
#
# 6
# CentralDiligence
#
#
#
#
#
#
# 7
# Cvelocity
#
#
#
#
#
#
# 8
# delancey Street Lending
#
#
#
#
#
#
# 9
# delanceyStreetLending
#
#
#
#
#
#
# 10
# G & G Funding
#
#
#
#
#
#
# 11
# G&G Fund
#
#
#
#
#
#
# 12
# Lendbug
#
#
#
#
#
#
# 13
# Lendfi
#
#
# ACH DEBIT XXXXX5505 LENDFIRM LLC LOAN PYMT
# LENDFIRM XXXXXX3898 IL  - Card 55 #XX63 - Date 07/23/21 XXXXXXXXXXXXXXXXXXXXXXX XX51 - Card Withdrawal Debit
# LendFirm LLC     DES:LOAN PYMT  ID:XXX8059                   INDN:Thomas Brown            CO ID:1823
# LendFirm LLC     DES:LOAN PYMT  ID:XXX8059                   INDN:Thomas Brown            CO ID:1823
# LOAN PYMT LendFirm LLC 5505 AlexStokes ACH DEBIT
# LendFirm LLC     DES:LOAN PYMT  ID:XXX8059                   INDN:Thomas Brown            CO ID:1823
# ...

# %%
def Find_MCA2(tt):
    #ttt["transaction_type"] = tt["transaction_type"]
    cnt=1
    for j in lst:
        print(cnt)
        print(j)
        print("\n")
        for a,b in tt.iterrows():
            try:
                if re.search(r"(?i)\b"+j+r"",b["Keyword"]):
                    print("Keyword")
                    print(b["Keyword"])
                if re.search(r"(?i)\b"+j+r"",b["Source"]):
                    print("Source")
                    print(b["Source"])
            except:
                None
    
        cnt+=1
        #print("\n\n\n")

# %%
tt = pd.read_excel("C:/Users/nelson.wang/OneDrive/classification/Classification-keyword(dictionary).xlsx")

# %%
tt = tt.sort_values("Keyword",ascending=True)
tt
# Out:
#         id               Keyword                       Category  \
# 3497  1672                  ADP                Paychecks/Salary
# 3526  1673                  ADP                Paychecks/Salary
# 175    495          ADVANCE AUTO  Automotive Repair/Maintenance
# 333    496          ADVANCE AUTO            Automotive Expenses
# 3638  1739                  AMC                   Entertainment
# ...    ...                   ...                            ...
# 2408   221             uibenefit                            NaN
# 2400   213      unemployment%ins                            NaN
# 2399   212  unemployment%payment                            NaN
# 2414   227            unemplymnt                            NaN
# 4236    96          x4110 NJ WEB                          Taxes
#
#                              Classification        Group  rank trans_type  \
# 3497                         Payroll Credit      Revenue     9     CREDIT
# ...

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Report")
lst = list(df["Lender Name"])
len(lst)
# Out:
# 221

# %%
# %%time
Find_MCA2(tt)
# Out:
# 1
# 1st Merchant Funding
#
#
# Source
# 1st Merchant Funding
# Source
# 1st Merchant Funding
# 2
# 24 Capital
#
#
# 3
# 60 Day Capital
#
#
# 4
# 6th Ave Capital (closed)
#
#
# 5
# Acarius
#
#
# 6
# Accord Business Funding
#
#
# 7
# Advantage Capital
#
#
# 8
# Advantage Capital
#
#
# 9
# Advantage Capital
#
#
# 10
# AJ Equity
#
#
# 11
# AJ Equity
#
#
# 12
# Alfa Advance
#
#
# 13
# Alva Advance
#
#
# 14
# AMEX
#
#
# Keyword
# AMEX - DEBIT ACH DEBITACH
# Keyword
# AMEX - DEBIT ACH DEBITACH
# Keyword
# AMEX BILL
# Keyword
# AMEX EPAYMENT
# Keyword
# AMEX UPS PMT
# Keyword
# AMEX UPS PMT
# Keyword
# AMEX%DEBIT ACH DEBITACH
# Keyword
# AMEX%DEBIT ACH DEBITACH
# Keyword
# AMEX%DEBIT%ACH%DEBITA
# Keyword
# AMEX%DEBIT%ACH%DEBITA
# Keyword
# AMEX%EPAYMENTTYPE
# Keyword
# AMEX%EPayment%ACH%PMT
# 15
# Amsterdam Capital Solutions
#
#
# 16
# Amsterdam Capital Solutions
#
#
# 17
# Apex Funding
#
#
# 18
# ARF Financial
#
#
# Keyword
# ARF FINANCIAL
# Source
# ARF Financial
# Keyword
# ARF FINANCIAL
# ...

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Search")
lst = list(df["Search"])
len(lst)
# Out:
# 130

# %%
# %%time
Find_MCA2(tt)
# Out:
# 1
# 24 Capital
#
#
# 2
# 60 Day Capital
#
#
# 3
# 6th Ave Capital
#
#
# 4
# Acarius
#
#
# 5
# AJ
#
#
# 6
# Alfa
#
#
# 7
# Alva
#
#
# 8
# AMEX
#
#
# Keyword
# AMEX - DEBIT ACH DEBITACH
# Keyword
# AMEX - DEBIT ACH DEBITACH
# Keyword
# AMEX BILL
# Keyword
# AMEX EPAYMENT
# Keyword
# AMEX UPS PMT
# Keyword
# AMEX UPS PMT
# Keyword
# AMEX%DEBIT ACH DEBITACH
# Keyword
# AMEX%DEBIT ACH DEBITACH
# Keyword
# AMEX%DEBIT%ACH%DEBITA
# Keyword
# AMEX%DEBIT%ACH%DEBITA
# Keyword
# AMEX%EPAYMENTTYPE
# Keyword
# AMEX%EPayment%ACH%PMT
# 9
# Amsterdam
#
#
# 10
# ARF
#
#
# Keyword
# ARF FINANCIAL
# Source
# ARF Financial
# Keyword
# ARF FINANCIAL
# Source
# ARF Financial
# 11
# Avanza
#
#
# 12
# Basepoint
#
#
# 13
# BFS
#
#
# Source
# BFS Capital
# Source
# BFS Capital
# Keyword
# BUSINESS FINAN BFS
# Source
# BFS Capital
# Keyword
# BUSINESS FINAN BFS
# Source
# BFS Capital
# Source
# BFS Capital
# Source
# BFS Capital
# Source
# BFS Capital
# Source
# BFS Capital
# 14
# Bitty
#
#
# 15
# Blade
#
#
# ...

# %%
tt = pd.read_excel("MASTER-2022_V9.xlsx")

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Report")
lst = list(df["Lender Name"])
len(lst)

# %%
# %%time
Find_MCA2(tt)

# %%
df = pd.read_excel("MCA list.xlsx", sheet_name="Search")
lst = list(df["Search"])
len(lst)
# Out:
# 130

# %%
# %%time
Find_MCA2(tt)
# Out:
# 1
# 24 Capital
#
#
# 2
# 60 Day Capital
#
#
# 3
# 6th Ave Capital
#
#
# 4
# Acarius
#
#
# 5
# AJ
#
#
# 6
# Alfa
#
#
# 7
# Alva
#
#
# 8
# AMEX
#
#
# Keyword
# AMEX%DEBIT%ACH%DEBITA
# Keyword
# AMEX%DEBIT%ACH%DEBITA
# Keyword
# AMEX - DEBIT ACH DEBITACH
# Keyword
# AMEX%DEBIT ACH DEBITACH
# Keyword
# AMEX - DEBIT ACH DEBITACH
# Keyword
# AMEX%DEBIT ACH DEBITACH
# Keyword
# AMEX EPAYMENT
# Keyword
# AMEX%EPayment%ACH%PMT
# Keyword
# AMEX%EPAYMENTTYPE
# Keyword
# AMEX BILL
# Keyword
# AMEX UPS PMT
# Keyword
# AMEX UPS PMT
# 9
# Amsterdam
#
#
# 10
# ARF
#
#
# Keyword
# ARF FINANCIAL
# Source
# ARF Financial
# Keyword
# ARF FINANCIAL
# Source
# ARF Financial
# 11
# Avanza
#
#
# 12
# Basepoint
#
#
# 13
# BFS
#
#
# Source
# BFS Capital
# Source
# BFS Capital
# Keyword
# BUSINESS FINAN BFS
# Source
# BFS Capital
# Keyword
# BUSINESS FINAN BFS
# Source
# BFS Capital
# Source
# BFS Capital
# Source
# BFS Capital
# Source
# BFS Capital
# Source
# BFS Capital
# 14
# Bitty
#
#
# 15
# Blade
#
#
# ...

# %% [markdown]
# # Find Lead Id

# %%
df_20q1 = pd.read_csv("df_202001.csv")
df_20q2= pd.read_csv("df_202004.csv")
df_20q3= pd.read_csv("df_202007.csv")
df_20q4= pd.read_csv("df_202010.csv")

df_20q1_cr = df_20q1.loc[df_20q1["transaction_type"]=="credit"]
df_20q1_db = df_20q1.loc[df_20q1["transaction_type"]=="debit"]

df_20q2_cr = df_20q2.loc[df_20q2["transaction_type"]=="credit"]
df_20q2_db = df_20q2.loc[df_20q2["transaction_type"]=="debit"]

df_20q3_cr = df_20q3.loc[df_20q3["transaction_type"]=="credit"]
df_20q3_db = df_20q3.loc[df_20q3["transaction_type"]=="debit"]

df_20q4_cr = df_20q4.loc[df_20q4["transaction_type"]=="credit"]
df_20q4_db = df_20q4.loc[df_20q4["transaction_type"]=="debit"]



df_21q1= pd.read_csv("df_202101.csv")
df_21q2= pd.read_csv("df_202104.csv")
df_21q3= pd.read_csv("df_202107.csv")
df_21q4= pd.read_csv("df_202110.csv")

df_21q1_cr = df_21q1.loc[df_21q1["transaction_type"]=="credit"]
df_21q1_db = df_21q1.loc[df_21q1["transaction_type"]=="debit"]

df_21q2_cr = df_21q2.loc[df_21q2["transaction_type"]=="credit"]
df_21q2_db = df_21q2.loc[df_21q2["transaction_type"]=="debit"]

df_21q3_cr = df_21q3.loc[df_21q3["transaction_type"]=="credit"]
df_21q3_db = df_21q3.loc[df_21q3["transaction_type"]=="debit"]

df_21q4_cr = df_21q4.loc[df_21q4["transaction_type"]=="credit"]
df_21q4_db = df_21q4.loc[df_21q4["transaction_type"]=="debit"]



df_22q1 = pd.read_csv("df_202201.csv")
df_22q2 = pd.read_csv("df_202204.csv")
df_22q3 = pd.read_csv("df_202207.csv")

df_22q1_cr = df_22q1.loc[df_22q1["transaction_type"]=="credit"]
df_22q1_db = df_22q1.loc[df_22q1["transaction_type"]=="debit"]

df_22q2_cr = df_22q2.loc[df_22q2["transaction_type"]=="credit"]
df_22q2_db = df_22q2.loc[df_22q2["transaction_type"]=="debit"]

df_22q3_cr = df_22q3.loc[df_22q3["transaction_type"]=="credit"]
df_22q3_db = df_22q3.loc[df_22q3["transaction_type"]=="debit"]

# %%
df_20q2= pd.read_csv("df_202004.csv")
df_20q2_db = df_20q2.loc[df_20q2["transaction_type"]=="debit"]

# %%
def Find_MCA3(tt):
    cnt = 0
    #ttt["transaction_type"] = tt["transaction_type"]
    for a,b in tt.iterrows():
        try:
            if re.search(r"(?i)\b"+j+r"",b["description"]):
                cnt+=1
                print(b)
                print(b["description"])
                if cnt >=3:
                    break
        except:
            None
    print("\n\n\n")

# %%
df_20q2= pd.read_csv("df_202004.csv")
df_20q2_db = df_20q2.loc[df_20q2["transaction_type"]=="debit"]

# %%
j = "60 day cap"
Find_MCA3(df_20q2_db)
# Out:
# Unnamed: 0                             3711168
# Unnamed: 0.1                             35323
# Lead Id                                 589143
# account_number                            x575
# post_date                           2020-04-02
# description         ACH 60 DAY CAP MDS XXX7950
# transaction_type                         debit
# amount                                   250.0
# running_balance                       -2342.12
# Classification             Unclassified Debits
# Source_class                               NaN
# Source                                     NaN
# Name: 69346, dtype: object
# ACH 60 DAY CAP MDS XXX7950
# Unnamed: 0                             5350085
# Unnamed: 0.1                            888206
# Lead Id                                 589143
# account_number                            x575
# post_date                           2020-05-04
# description         ACH 60 DAY CAP MDS XXX9824
# transaction_type                         debit
# ...

# %%
for i,j in df_mc.iterrows():
    if re.search(r"mission",j["description"]):
        print(j)
        print(j["description"])
# Out:
# Unnamed: 0                                                    1242695
# Lead Id                                                       1264905
# account_number                                                   3736
# post_date                                                  2021-09-10
# description         total deposits and additions fedwire credit vi...
# transaction_type                                               credit
# amount                                                        12392.0
# running_balance                                               7042.13
# Classification                                          Trade Revenue
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 2418959, dtype: object
# ...

# %%
for i,j in df_irm.iterrows():
    if re.search(r"(?i)irm",j["description"]):
        print(j)
        print(j["description"])
# Out:
# Unnamed: 0                                                    1944651
# Lead Id                                                        834549
# account_number                                                   4164
# post_date                                                  2021-10-26
# description         CORPORATE ACH XXXXXX2241 IRM VENTURES CAP ACH PMT
# transaction_type                                               credit
# amount                                                         3200.0
# running_balance                                               5444.88
# Classification                                          Trade Revenue
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 12883296, dtype: object
# CORPORATE ACH XXXXXX2241 IRM VENTURES CAP ACH PMT

# %%
for i,j in df_len.iterrows():
    if re.search(r"(?i)funding",j["description"]):
        print(j)
        print(j["description"])
# Out:
# Unnamed: 0                                                    1734200
# Lead Id                                                        593927
# account_number                                                   5661
# post_date                                                  2020-02-26
# description         BOOK TRANSFER CREDIT B/O: FUNDING METRICS LLC ...
# transaction_type                                               credit
# amount                                                        29105.0
# running_balance                                              32387.06
# Classification                                           Debt Accrual
# Source_class                                              Other Loans
# Source                                                     Misc Loans
# Name: 2531846, dtype: object
# BOOK TRANSFER CREDIT B/O: FUNDING METRICS LLC JERSEY CITY NJ 073

# %%
cnt=0
for i,j in df_ft.iterrows():
    if re.search(r"(?i)rdm",j["description"]):
        print(j)
        print(j["description"])
        cnt+=1
        if cnt>0:
            break
# Out:
# Unnamed: 0                                                     150587
# Lead Id                                                        592990
# account_number                                                   1533
# post_date                                                  2021-01-22
# description         Corporate ACH Rdm Rdm Capital Fund Irrt45876 0...
# transaction_type                                                debit
# amount                                                           89.0
# running_balance                                               4299.46
# Classification                                       Misc Fee Charges
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 25035267, dtype: object
# Corporate ACH Rdm Rdm Capital Fund Irrt45876 00021022910932486

# %%
cnt=0
for i,j in df_keo.iterrows():
    if re.search(r"(?i)mo tech",j["description"]):
        print(j)
        print(j["description"])
        cnt+=1
        if cnt>0:
            break
# Out:
# Unnamed: 0                                                    1067598
# Lead Id                                                        849223
# account_number                                                   5191
# post_date                                                  2020-11-09
# description         orig co name:mo technologies orig id:182471199...
# transaction_type                                                debit
# amount                                                         1000.0
# running_balance                                              -1059.96
# Classification                                         Trade Payments
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 17574432, dtype: object
# ...

# %%
SRS CAPITAL /20q2 db = 648710 

HUNTER CAROLINE / 22q2 db= 1383697

#SPG ADV / 22q2 db = 1325241

SPLASH ADVANCE / 22q3 db = 1439580/1435122

#BITTY ADVANCE / 22q1 db= 1339915/1433992

#DAKA CAPITAL / 21q4 db= 591464


--------------------------------------------------------------

#Main Street Finance / 22q3 db = 971148

#Lifetime Funding / 22q3 db = 1173948

#Inadvance(in advance cap/ in advance group) /22q2 db = 1361977

#Main St Cash / 22q2 db = 971891

#Flash Advance / 22q2 db = 1418701

Mission Capital / 21q4 db = 1264905

IRM Capital / 21q4 db = 834549

KEO World / 20q4 cr = 849223

Lendini(Funding Metrics) / 20q2 db = 593927

fintap/ 22q3 = 592990 

60 day cap / 20q2db = 589143 / 626070

# %%
df_20q2= pd.read_csv("df_202004.csv")
df_20q2_db = df_20q2.loc[df_20q2["transaction_type"]=="debit"]

# %%
#Find lead ID:
j = "60 day cap"
Find_MCA3(df_20_db)
# Out:
# Unnamed: 0                                                     619565
# Lead Id                                                        626070
# account_number                                                   7311
# post_date                                                  2020-02-18
# description         02/18 online domestic wire transfer via: td ba...
# transaction_type                                                debit
# amount                                                         1300.0
# running_balance                                              32238.75
# Classification                                  Returns/Refunds Debit
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 1192179, dtype: object
# ...

# %%
#Use lead ID to find
df_60 = df_20_cr.loc[df_20_cr["Lead Id"] == 589143]
df_60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 7026 to 5350089
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        51 non-null     int64
#  1   Lead Id           51 non-null     int64
#  2   account_number    51 non-null     object
#  3   post_date         51 non-null     object
#  4   description       51 non-null     object
#  5   transaction_type  51 non-null     object
#  6   amount            51 non-null     float64
#  7   running_balance   51 non-null     float64
#  8   Classification    51 non-null     object
#  9   Source_class      1 non-null      object
#  10  Source            1 non-null      object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 4.8+ KB

# %%
cnt=0
for i,j in df_60.iterrows():
    if re.search(r"(?i)60 day",j["description"]):
        print(j)
        print(j["description"])
        cnt+=1
        if cnt>0:
            break
# Out:
# Unnamed: 0                             2005637
# Lead Id                                 589143
# account_number                            x575
# post_date                           2020-03-04
# description         ACH 60 DAY CAP MDS XXX4259
# transaction_type                        credit
# amount                                  2994.0
# running_balance                        -265.66
# Classification            Unclassified Credits
# Source_class                               NaN
# Source                                     NaN
# Name: 2798336, dtype: object
# ACH 60 DAY CAP MDS XXX4259

# %%
df_22 = pd.read_csv("df_trx_202107_202208.csv")
df_22_cr = df_22.loc[df_22["transaction_type"]=="credit"]
df_22_db = df_22.loc[df_22["transaction_type"]=="debit"]

# %%
df_22_db = df_22.loc[df_22["transaction_type"]=="debit"]

# %%
df_20 = pd.read_csv("df_trx_202001_202106.csv")
df_20_cr = df_20.loc[df_20["transaction_type"]=="credit"]
df_20_db = df_20.loc[df_20["transaction_type"]=="debit"]

# %%
#df_spg = df_22_cr.loc[df_22_cr["Lead Id"] == 1325241]
df_spg2 = df_20_cr.loc[df_20_cr["Lead Id"] == 1325241]
df_spg2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292 entries, 47589973 to 47593932
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        292 non-null    int64
#  1   Lead Id           292 non-null    int64
#  2   account_number    292 non-null    object
#  3   post_date         292 non-null    object
#  4   description       292 non-null    object
#  5   transaction_type  292 non-null    object
#  6   amount            292 non-null    float64
#  7   running_balance   292 non-null    float64
#  8   Classification    292 non-null    object
#  9   Source_class      1 non-null      object
#  10  Source            1 non-null      object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 27.4+ KB

# %%
for i,j in df_spg.iterrows():

    if j["amount"] == 13950.0:
        print(j)
        print(j["description"])
    '''print(j["amount"])
    print(j["description"])
    print("\n")'''
# Out:
# Unnamed: 0                                                    3589460
# Lead Id                                                       1325241
# account_number                                                   5407
# post_date                                                  2021-08-13
# description         SPG ADVANCE      DES:Joy Hernan ID:XXXXXXXX540...
# transaction_type                                               credit
# amount                                                        13950.0
# running_balance                                              12304.68
# Classification                           Insurance Claims/Commissions
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 5638542, dtype: object
# SPG ADVANCE      DES:Joy Hernan ID:XXXXXXXX5407              INDN:Joy Hernandez Insuranc  CO ID:XXXXXX1295 CCD           PMT INFO:Joy Hernandez Insurance Solutions

# %%
#df_spl1 = df_22_cr.loc[df_22_cr["Lead Id"] == 1439580]
df_spl1 = df_20_cr.loc[df_20_cr["Lead Id"] == 1439580]
df_spl1.info()

#df_spl2 = df_22_cr.loc[df_22_cr["Lead Id"] == 1435122]
df_spl2 = df_20_cr.loc[df_20_cr["Lead Id"] == 1439580]
df_spl2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        0 non-null      int64
#  1   Lead Id           0 non-null      int64
#  2   account_number    0 non-null      object
#  3   post_date         0 non-null      object
#  4   description       0 non-null      object
#  5   transaction_type  0 non-null      object
#  6   amount            0 non-null      float64
#  7   running_balance   0 non-null      float64
#  8   Classification    0 non-null      object
#  9   Source_class      0 non-null      object
#  10  Source            0 non-null      object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 0.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
# ...

# %%
for i,j in df_spl1.iterrows():

    #if j["amount"] == 13950.0:
    #print(j)
    print(j["description"])
    '''print(j["amount"])
    print(j["description"])
    print("\n")'''
# Out:
# Online Banking transfer from CHK 9039                       Confirmation# XXXXXX2972
# Zelle Transfer Conf# yur0a7ifh;                             PHANOUVONG, KATHLEEN
# Zelle Transfer Conf# 0GDA56FH8;                             DEKINA WESTBROOK
# Zelle Transfer Conf# XXXXX9994;                             KATHLEEN VALERA
# Zelle Transfer Conf# grbmypmh8;                             VARGAS, ANGELA
# Zelle Transfer Conf# 0CXXX3597;                             Lola Allen
# Zelle Transfer Conf# gp0wa06tt;                             NOOD BEAUTY, CORP
# Prfd Rwds for Bus-ATM Operator Refund of $6.95
# MIA CLINIC       DES:RH MIAMI   ID:Plush Wellness            INDN:Plush Wellness          CO ID:XXXXX0427  PPD
# Zelle Transfer Conf# 0GDB5UQAV;                             JODIANN OYESHOLA
# Zelle Transfer Conf# 0GDB5NJVC;                             DEKINA WESTBROOK
# Zelle Transfer Conf# T0C3XTGHW;                             ZHAMARIAH FISHER
# ...

# %%
#df_bit1 = df_22_cr.loc[df_22_cr["Lead Id"] == 1339915]
#df_bit1 = df_20_cr.loc[df_20_cr["Lead Id"] == 1339915]
#df_bit1.info()

df_bit2 = df_22_cr.loc[df_22_cr["Lead Id"] == 1433992]
#df_bit2 = df_20_cr.loc[df_20_cr["Lead Id"] == 1433992]
df_bit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 5028674 to 35026064
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        136 non-null    int64
#  1   Lead Id           136 non-null    int64
#  2   account_number    136 non-null    object
#  3   post_date         136 non-null    object
#  4   description       136 non-null    object
#  5   transaction_type  136 non-null    object
#  6   amount            136 non-null    float64
#  7   running_balance   136 non-null    float64
#  8   Classification    136 non-null    object
#  9   Source_class      0 non-null      object
#  10  Source            0 non-null      object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 12.8+ KB

# %%
for i,j in df_bit2.iterrows():
    if j["description"] =="ORIG CO NAME:MCA SERVICING          ORIG ID:XXXXXX2757 DESC DATE:XX1208 CO ENTRY DESCR:XXXXXX3863SEC:CCD    TRACE#:XXXXXXXXXXX7476 EED:XX1209   IND ID:FUNXXXXXXXX3318              IND NAME:YU DONG":
        print(j)
# Out:
# Unnamed: 0                                                    5395242
# Lead Id                                                       1433992
# account_number                                                   0597
# post_date                                                  2021-12-09
# description         ORIG CO NAME:MCA SERVICING          ORIG ID:XX...
# transaction_type                                               credit
# amount                                                         2606.0
# running_balance                                               1504.03
# Classification                                          Trade Revenue
# Source_class                                                      NaN
# Source                                                            NaN
# Name: 16299871, dtype: object

# %%
#df_dak = df_22_cr.loc[df_22_cr["Lead Id"] == 591464]
df_dak = df_20_cr.loc[df_20_cr["Lead Id"] == 591464]
df_dak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 46336523 to 46336775
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        33 non-null     int64
#  1   Lead Id           33 non-null     int64
#  2   account_number    33 non-null     object
#  3   post_date         33 non-null     object
#  4   description       33 non-null     object
#  5   transaction_type  33 non-null     object
#  6   amount            33 non-null     float64
#  7   running_balance   33 non-null     float64
#  8   Classification    33 non-null     object
#  9   Source_class      4 non-null      object
#  10  Source            4 non-null      object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 3.1+ KB

# %%
for i,j in df_dak.iterrows():
    if j["description"] =="ORIG CO NAME:Daka Capital Gro ORIG ID:XXXXXX8064 DESC DATE:XX0630 CO ENTRY DESCR:Funding SEC:CCD TRACE#:XXXXXXXXXXX7468 EED:XX0630 IND ID:XX0852 IND NAME:GOGALEX LLC TRN: 1XXXXX7468TC":
        print(j)
# Out:
# Unnamed: 0                                                    7695747
# Lead Id                                                        591464
# account_number                                                   5982
# post_date                                                  2021-06-30
# description         ORIG CO NAME:Daka Capital Gro ORIG ID:XXXXXX80...
# transaction_type                                               credit
# amount                                                        16002.0
# running_balance                                              36394.28
# Classification                                           Debt Accrual
# Source_class                                              Other Loans
# Source                                                     Misc Loans
# Name: 46336523, dtype: object

# %%
Unnamed: 0                                                    3589460
Lead Id                                                       1325241
account_number                                                   5407
post_date                                                  2021-08-13
description         SPG ADVANCE      DES:Joy Hernan ID:XXXXXXXX540...
transaction_type                                               credit
amount                                                        13950.0
running_balance                                              12304.68
Classification                           Insurance Claims/Commissions
Source_class                                                      NaN
Source                                                            NaN
Name: 5638542, dtype: object
        
SPG ADVANCE      DES:Joy Hernan ID:XXXXXXXX5407              INDN:Joy Hernandez Insuranc  CO ID:XXXXXX1295 CCD           PMT INFO:Joy Hernandez Insurance Solutions

# %%
Unnamed: 0                                                    5395242
Lead Id                                                       1433992
account_number                                                   0597
post_date                                                  2021-12-09
description         ORIG CO NAME:MCA SERVICING          ORIG ID:XX...
transaction_type                                               credit
amount                                                         2606.0
running_balance                                               1504.03
Classification                                          Trade Revenue
Source_class                                                      NaN
Source                                                            NaN
Name: 16299871, dtype: object

ORIG CO NAME:MCA SERVICING          ORIG ID:XXXXXX2757 DESC DATE:XX1208 CO ENTRY DESCR:XXXXXX3863SEC:CCD    TRACE#:XXXXXXXXXXX7476 EED:XX1209   IND ID:FUNXXXXXXXX3318              IND NAME:YU DONG

# %%
Unnamed: 0                                                    7695747
Lead Id                                                        591464
account_number                                                   5982
post_date                                                  2021-06-30
description         ORIG CO NAME:Daka Capital Gro ORIG ID:XXXXXX80...
transaction_type                                               credit
amount                                                        16002.0
running_balance                                              36394.28
Classification                                           Debt Accrual
Source_class                                              Other Loans
Source                                                     Misc Loans
Name: 46336523, dtype: object
        
ORIG CO NAME:Daka Capital Gro ORIG ID:XXXXXX8064 DESC DATE:XX0630 CO ENTRY DESCR:Funding SEC:CCD TRACE#:XXXXXXXXXXX7468 EED:XX0630 IND ID:XX0852 IND NAME:GOGALEX LLC TRN: 1XXXXX7468TC
